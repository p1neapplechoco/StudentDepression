# %% [markdown]
# # Phân tích Nhóm biến Học tập - Công việc
#
# Notebook này tập trung phân tích các biến liên quan đến khía cạnh học tập và công việc của sinh viên, bao gồm:
# - **CGPA**: Điểm trung bình tích lũy.
# - **Degree**: Bằng cấp/Trình độ học vấn.
# - **Work/Study Hours**: Số giờ làm việc/học tập mỗi ngày.
# - **Profession**: Nghề nghiệp
#
# Mục tiêu là tìm hiểu mối liên hệ giữa các yếu tố này và tình trạng trầm cảm (**Depression**) của sinh viên.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import warnings

# Cấu hình hiển thị
warnings.filterwarnings('ignore')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['font.size'] = 11

# %%
# Đọc dữ liệu
df = pd.read_csv('../data/student_depression_dataset.csv')

# Danh sách các biến cần phân tích
study_cols = ['CGPA', 'Degree', 'Work/Study Hours', 'Depression']

# Hiển thị thông tin cơ bản
print(f'Kích thước dữ liệu: {df.shape[0]:,} dòng x {df.shape[1]} cột')
print('\n Các cột liên quan đến học tập và công việc:')
df[study_cols].info()
print('\n Thống kê mô tả:')
display(df[study_cols].describe())
# Out:
# Kích thước dữ liệu: 27,901 dòng x 18 cột
#
#  Các cột liên quan đến học tập và công việc:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27901 entries, 0 to 27900
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CGPA              27901 non-null  float64
#  1   Degree            27901 non-null  object
#  2   Work/Study Hours  27901 non-null  float64
#  3   Depression        27901 non-null  int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 872.0+ KB
#
#  Thống kê mô tả:
#                CGPA  Work/Study Hours    Depression
# count  27901.000000      27901.000000  27901.000000
# mean       7.656104          7.156984      0.585499
# std        1.470707          3.707642      0.492645
# min        0.000000          0.000000      0.000000
# 25%        6.290000          4.000000      0.000000
# 50%        7.770000          8.000000      1.000000
# ...

# %%
# Phân tích phân bố các biến định lượng
num_vars = ['CGPA', 'Work/Study Hours']

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
axes = axes.flatten()

for i, var in enumerate(num_vars):
    sns.histplot(data=df, x=var, kde=True, ax=axes[i], bins=15)
    axes[i].set_title(f'Phân bố của {var}')

plt.tight_layout()
plt.show()

# %%
# Phân tích phân bố biến định tính: Degree và Depression
fig, axes = plt.subplots(2, 1, figsize=(14, 10))

# Degree - Chỉ hiển thị top 15 phổ biến nhất
degree_counts = df['Degree'].value_counts().head(15)
axes[0].barh(range(len(degree_counts)), degree_counts.values)
axes[0].set_yticks(range(len(degree_counts)))
axes[0].set_yticklabels(degree_counts.index)
axes[0].set_xlabel('Số lượng sinh viên')
axes[0].set_title(f'Top 15 Degree phổ biến nhất (Tổng: {df["Degree"].nunique()} loại)')
axes[0].invert_yaxis()
# Thêm giá trị lên thanh
for i, v in enumerate(degree_counts.values):
    axes[0].text(v + 50, i, str(v), va='center')

# Depression
sns.countplot(data=df, x='Depression', ax=axes[1])
axes[1].set_title('Phân bố của Depression')
for container in axes[1].containers:
    axes[1].bar_label(container)

plt.tight_layout()
plt.show()

# In tỷ lệ
print(f'\nTỷ lệ trầm cảm: {df["Depression"].mean()*100:.1f}%')
print(f'\nPhân bố theo Degree (Top 10):')
print(df['Degree'].value_counts().head(10))
print(f'\nTổng số loại Degree: {df["Degree"].nunique()}')
# Out:
# Tỷ lệ trầm cảm: 58.5%
#
# Phân bố theo Degree (Top 10):
# Degree
# 'Class 12'    6080
# B.Ed          1867
# B.Com         1506
# B.Arch        1478
# BCA           1433
# MSc           1190
# B.Tech        1152
# MCA           1044
# M.Tech        1022
# BHM            925
# Name: count, dtype: int64
#
# Tổng số loại Degree: 28

# %%
# Làm sạch dữ liệu
# Chuyển đổi các biến định lượng sang kiểu số (nếu cần) và xử lý giá trị thiếu
for var in num_vars:
    df[var] = pd.to_numeric(df[var], errors='coerce')

# Kiểm tra giá trị thiếu
print('Số lượng giá trị thiếu trước khi xử lý:')
print(df[study_cols].isnull().sum())

# Lấp đầy giá trị thiếu bằng trung vị (median) cho biến số
for var in num_vars:
    df[var] = df[var].fillna(df[var].median())

# Xử lý biến Degree: điền bằng Mode
mode_degree = df['Degree'].mode()[0]
df['Degree'] = df['Degree'].fillna(mode_degree)

# Loại bỏ dòng thiếu Depression (nếu có)
df = df.dropna(subset=['Depression'])

print('\nSố lượng giá trị thiếu sau khi xử lý:')
print(df[study_cols].isnull().sum())
# Out:
# Số lượng giá trị thiếu trước khi xử lý:
# CGPA                0
# Degree              0
# Work/Study Hours    0
# Depression          0
# dtype: int64
#
# Số lượng giá trị thiếu sau khi xử lý:
# CGPA                0
# Degree              0
# Work/Study Hours    0
# Depression          0
# dtype: int64

# %%
# Tương quan giữa các biến định lượng và Depression
corr_vars = num_vars + ['Depression']
plt.figure(figsize=(10, 8))
correlation = df[corr_vars].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Tương quan giữa các biến Học tập/Công việc và Trầm cảm')
plt.show()

# %%
# In ra các cặp biến có tương quan cao nhất
corr_unstack = correlation.unstack()
corr_sorted = corr_unstack.sort_values(kind='quicksort', ascending=False)
print('Top correlations:')
print(corr_sorted[corr_sorted != 1.0].head(10))
# Out:
# Top correlations:
# Work/Study Hours  Depression          0.208563
# Depression        Work/Study Hours    0.208563
# CGPA              Depression          0.022210
# Depression        CGPA                0.022210
# Work/Study Hours  CGPA                0.002604
# CGPA              Work/Study Hours    0.002604
# dtype: float64

# %% [markdown]
# ## Insights từ EDA
#
# Dựa trên các biểu đồ và phân tích tương quan trên, chúng ta có những phát hiện quan trọng:
#
# ### Thống kê mô tả:
# - **Tỷ lệ trầm cảm**: 58.5% - khá cao trong mẫu nghiên cứu
# - **CGPA trung bình**: 7.66/10 (khá tốt, phân phối gần chuẩn)
# - **Work/Study Hours trung bình**: 7.16 giờ/ngày (dao động từ 0-12 giờ)
#
# ### Mối tương quan với Depression:
# 1. **Work/Study Hours ↔ Depression: r = 0.21** **Tương quan dương mạnh nhất**
#    - Số giờ học/làm việc cao **liên quan đến** tỷ lệ trầm cảm cao hơn
# 2. **CGPA ↔ Depression: r = 0.02** - Tương quan **rất yếu**, không có ý nghĩa thực tiễn
#    - CGPA dường như **không phải** yếu tố quyết định
#
# ### Phân bố Degree:
# - Có **28 loại bằng cấp** khác nhau
# - Phổ biến nhất: Class 12 (6,080 người), B.Ed (1,867), B.Com (1,506)
# - Cần phân tích sâu hơn về tỷ lệ trầm cảm theo từng ngành
#
# ## Research Questions
#
# Dựa trên insights trên, chúng ta đặt ra các câu hỏi nghiên cứu:
#
# 1.  **RQ7 - Các yếu tố học tập ảnh hưởng đến Trầm cảm**: *CGPA và Work/Study Hours có tác động như thế nào đến nguy cơ trầm cảm? Yếu tố nào quan trọng hơn?*
#
# 2.  **RQ8 - Sự khác biệt theo Bằng cấp**: *Nhóm ngành học/bằng cấp nào có tỷ lệ trầm cảm cao hơn đáng kể so với mức trung bình (58.5%)?*
#
# 3.  **RQ9 - Ngưỡng rủi ro Work/Study Hours**: *Tại mức thời gian học/làm việc nào thì xác suất mắc trầm cảm bắt đầu vượt quá 50%? Có ngưỡng "an toàn" nào không?*
#
# 4.  **RQ10 - Nghịch lý CGPA cao - Satisfaction thấp**: *Sinh viên có CGPA cao nhưng Study Satisfaction thấp có tỷ lệ trầm cảm cao hơn không? Liệu "học giỏi nhưng không hạnh phúc" có phải là yếu tố rủi ro?*

# %% [markdown]
# # Thực hiện Experiments để trả lời Research Questions
#
# Chúng ta sẽ thực hiện các phân tích thống kê và mô hình hóa để trả lời 4 câu hỏi nghiên cứu trên.
#
# ## Chuẩn bị dữ liệu
# - Biến mục tiêu `Depression` đã là dạng số (0, 1).
# - Biến `Degree` là biến phân loại, sẽ được sử dụng cho phân tích so sánh (RQ2).
# - Các biến `CGPA` và `Work/Study Hours` là biến định lượng, dùng cho hồi quy (RQ1, RQ3).

# %%
## RQ7: Tác động của CGPA và Work/Study Hours lên Trầm cảm

# 1. Mô hình Hồi quy Logistic
# Biến độc lập: CGPA, Work/Study Hours
X_rq1 = df[['CGPA', 'Work/Study Hours']]
X_rq1 = sm.add_constant(X_rq1)
y_rq1 = df['Depression']

model_rq1 = sm.Logit(y_rq1, X_rq1)
result_rq1 = model_rq1.fit()
print(result_rq1.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.656370
#          Iterations 4
#                            Logit Regression Results
# ...
# Dep. Variable:             Depression   No. Observations:                27901
# Model:                          Logit   Df Residuals:                    27898
# Method:                           MLE   Df Model:                            2
# Date:                Sat, 27 Dec 2025   Pseudo R-squ.:                 0.03255
# Time:                        19:37:23   Log-Likelihood:                -18313.
# converged:                       True   LL-Null:                       -18930.
# Covariance Type:            nonrobust   LLR p-value:                2.490e-268
# ...
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.7101      0.070    -10.147      0.000      -0.847      -0.573
# ...

# %%
# Heatmap cho tỷ lệ trầm cảm theo Work/Study Hours bins
work_bins = pd.cut(df['Work/Study Hours'], bins=[0, 3, 6, 9, 12], labels=['0-3h', '3-6h', '6-9h', '9-12h'])
cgpa_bins = pd.cut(df['CGPA'], bins=[0, 6, 7, 8, 10], labels=['<6', '6-7', '7-8', '8+'])

heatmap_data = df.groupby([work_bins, cgpa_bins])['Depression'].mean().unstack()

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, fmt='.1%', cmap='YlOrRd', cbar_kws={'label': 'Tỷ lệ Trầm cảm'})
plt.title('Tỷ lệ Trầm cảm theo Work/Study Hours và CGPA')
plt.xlabel('CGPA')
plt.ylabel('Work/Study Hours')
plt.tight_layout()
plt.show()

print("\nMa trận tỷ lệ trầm cảm (Depression Rate):")
print((heatmap_data * 100).round(1))
# Out:
# Ma trận tỷ lệ trầm cảm (Depression Rate):
# CGPA                <6   6-7   7-8    8+
# Work/Study Hours
# 0-3h              36.6  48.1  41.6  47.2
# 3-6h              51.4  59.5  49.2  56.5
# 6-9h              59.6  60.1  59.3  61.7
# 9-12h             68.1  68.3  66.0  71.1

# %%
## RQ8: Sự khác biệt theo Bằng cấp (Degree)
from scipy.stats import chi2_contingency

# Tính tỷ lệ trầm cảm theo từng loại bằng cấp
degree_depression = df.groupby('Degree').agg({
    'Depression': ['mean', 'count']
}).round(3)
degree_depression.columns = ['Depression_Rate', 'Count']
degree_depression = degree_depression.sort_values('Depression_Rate', ascending=False).reset_index()

# Lọc các Degree có ít nhất 100 sinh viên để tránh bias
degree_depression_filtered = degree_depression[degree_depression['Count'] >= 100].copy()

# Chi-square test để kiểm tra sự khác biệt có ý nghĩa
contingency_table = pd.crosstab(df['Degree'], df['Depression'])
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print(f"\n=== KIỂM ĐỊNH CHI-SQUARE ===")
print(f"Chi-square statistic: {chi2:.4f}")
print(f"P-value: {p_value:.4e}")
print(f"Degrees of freedom: {dof}")

if p_value < 0.05:
    print(f"\nKết luận: CÓ sự khác biệt có ý nghĩa thống kê (p < 0.05)")
else:
    print(f"\nKết luận: KHÔNG có sự khác biệt có ý nghĩa thống kê (p >= 0.05)")

# Visualization
plt.figure(figsize=(14, 6))
bars = plt.barh(range(len(degree_depression_filtered)), 
                degree_depression_filtered['Depression_Rate'], 
                color=['red' if x > df['Depression'].mean() else 'green' 
                       for x in degree_depression_filtered['Depression_Rate']])
plt.yticks(range(len(degree_depression_filtered)), degree_depression_filtered['Degree'])
plt.xlabel('Tỷ lệ Trầm cảm')
plt.title(f'Tỷ lệ Trầm cảm theo Bằng cấp (n ≥ 100, p = {p_value:.4f})')
plt.axvline(x=df['Depression'].mean(), color='blue', linestyle='--', 
            label=f'Mức trung bình: {df["Depression"].mean():.1%}')

# Thêm annotation
for i, (idx, row) in enumerate(degree_depression_filtered.iterrows()):
    plt.text(row['Depression_Rate'] + 0.01, i, 
            f"{row['Depression_Rate']:.1%} (n={int(row['Count'])})", 
            va='center', fontsize=9)

plt.legend()
plt.tight_layout()
plt.show()

print('\nTop 5 bằng cấp có tỷ lệ trầm cảm cao nhất (n ≥ 100):')
display(degree_depression_filtered.head())
# Out:
# === KIỂM ĐỊNH CHI-SQUARE ===
# Chi-square statistic: 531.3557
# P-value: 5.1255e-95
# Degrees of freedom: 27
#
# Kết luận: CÓ sự khác biệt có ý nghĩa thống kê (p < 0.05)
# Top 5 bằng cấp có tỷ lệ trầm cảm cao nhất (n ≥ 100):
#        Degree  Depression_Rate  Count
# 0  'Class 12'            0.708   6080
# 2         BSc            0.589    888
# 3      B.Arch            0.589   1478
# 4         BBA            0.585    696
# 5        MBBS            0.580    696

# %%
## RQ9: Xác định "Ngưỡng chịu đựng" cho Work/Study Hours

# Tạo dữ liệu giả định
hours_range = np.linspace(df['Work/Study Hours'].min(), df['Work/Study Hours'].max(), 100)
mean_cgpa = df['CGPA'].mean()

X_pred_rq3 = pd.DataFrame({
    'const': 1.0,
    'CGPA': mean_cgpa,
    'Work/Study Hours': hours_range
})

# Dự báo
y_pred_prob_rq3 = result_rq1.predict(X_pred_rq3)

# Tìm ngưỡng
threshold_idx = np.where(y_pred_prob_rq3 > 0.5)[0]
threshold_val = None
if len(threshold_idx) > 0:
    threshold_val = hours_range[threshold_idx[0]]
    print(f'\n=== NGƯỠNG BÁO ĐỘNG ===')
    print(f'Ngưỡng báo động (Probability > 50%): Work/Study Hours = {threshold_val:.2f} giờ/ngày')
    print(f'Xác suất trầm cảm tại ngưỡng: {y_pred_prob_rq3[threshold_idx[0]]:.1%}')
else:
    print('\n=== CẢNH BÁO ===')
    print('Trong phạm vi dữ liệu, xác suất trung bình không vượt quá 50%.')
    print(f'Xác suất cao nhất: {y_pred_prob_rq3.max():.1%} tại {hours_range[y_pred_prob_rq3.argmax()]:.2f} giờ')

# Tính xác suất tại các mốc cụ thể
print(f'\nXác suất trầm cảm tại các mốc:')
for h in [0, 3, 6, 9, 12]:
    idx = np.argmin(np.abs(hours_range - h))
    prob = y_pred_prob_rq3[idx]
    print(f'  {h} giờ/ngày: {prob:.1%}')

# Vẽ biểu đồ
plt.figure(figsize=(10, 6))
plt.plot(hours_range, y_pred_prob_rq3, label='Predicted Probability', color='red', linewidth=2)
plt.axhline(y=0.5, color='grey', linestyle='--', label='Risk Threshold (50%)')

if threshold_val:
    plt.axvline(x=threshold_val, color='orange', linestyle='--', label=f'Threshold: {threshold_val:.2f} hours')
    plt.scatter([threshold_val], [0.5], color='black', zorder=5)

plt.title('Dự báo Xác suất Trầm cảm theo Số giờ Học/Làm việc')
plt.xlabel('Work/Study Hours')
plt.ylabel('Probability of Depression')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# === NGƯỠNG BÁO ĐỘNG ===
# Ngưỡng báo động (Probability > 50%): Work/Study Hours = 4.12 giờ/ngày
# Xác suất trầm cảm tại ngưỡng: 50.2%
#
# Xác suất trầm cảm tại các mốc:
#   0 giờ/ngày: 38.5%
#   3 giờ/ngày: 47.0%
#   6 giờ/ngày: 55.4%
#   9 giờ/ngày: 63.8%
#   12 giờ/ngày: 71.5%

# %%
## RQ10: Nghịch lý CGPA cao - Study Satisfaction thấp

# Phân nhóm sinh viên:
# - CGPA cao: >= 8.0 (khoảng 25% top)
# - Study Satisfaction thấp: <= 2 (mức thấp)

cgpa_threshold = df['CGPA'].quantile(0.75)  # Top 25%
satisfaction_threshold = 2  # Thang đo từ 1-5

# Tạo các nhóm
df['high_cgpa'] = df['CGPA'] >= cgpa_threshold
df['low_satisfaction'] = df['Study Satisfaction'] <= satisfaction_threshold

# Tạo 4 nhóm để so sánh
df['group'] = 'Other'
df.loc[(df['high_cgpa']) & (df['low_satisfaction']), 'group'] = 'High CGPA + Low Satisfaction'
df.loc[(df['high_cgpa']) & (~df['low_satisfaction']), 'group'] = 'High CGPA + High Satisfaction'
df.loc[(~df['high_cgpa']) & (df['low_satisfaction']), 'group'] = 'Low CGPA + Low Satisfaction'
df.loc[(~df['high_cgpa']) & (~df['low_satisfaction']), 'group'] = 'Low CGPA + High Satisfaction'

# Tính tỷ lệ trầm cảm theo nhóm
group_stats = df.groupby('group').agg({
    'Depression': ['mean', 'count']
}).round(3)
group_stats.columns = ['Depression_Rate', 'Count']
group_stats = group_stats.sort_values('Depression_Rate', ascending=False)

print(f'CGPA threshold (75th percentile): {cgpa_threshold:.2f}')
print(f'Study Satisfaction threshold: {satisfaction_threshold}')
print('\nTỷ lệ trầm cảm theo nhóm:')
print(group_stats)

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Bar chart - Depression rate by group
group_stats_sorted = group_stats.sort_values('Depression_Rate', ascending=True)
axes[0].barh(range(len(group_stats_sorted)), group_stats_sorted['Depression_Rate'], color=['green', 'yellow', 'orange', 'red'])
axes[0].set_yticks(range(len(group_stats_sorted)))
axes[0].set_yticklabels(group_stats_sorted.index)
axes[0].set_xlabel('Tỷ lệ Trầm cảm')
axes[0].set_title('Tỷ lệ Trầm cảm theo Nhóm CGPA-Satisfaction')
axes[0].axvline(x=df['Depression'].mean(), color='blue', linestyle='--', label=f'Average: {df["Depression"].mean():.1%}')
for i, v in enumerate(group_stats_sorted['Depression_Rate']):
    axes[0].text(v + 0.01, i, f'{v:.1%} (n={int(group_stats_sorted.iloc[i]["Count"])})', va='center')
axes[0].legend()

# Heatmap - Depression rate by CGPA and Satisfaction
pivot_data = df.groupby([pd.cut(df['CGPA'], bins=5), pd.cut(df['Study Satisfaction'], bins=5)])['Depression'].mean().unstack()
sns.heatmap(pivot_data, annot=True, fmt='.2f', cmap='RdYlGn_r', ax=axes[1], cbar_kws={'label': 'Depression Rate'})
axes[1].set_title('Heatmap: Tỷ lệ Trầm cảm theo CGPA và Study Satisfaction')
axes[1].set_xlabel('Study Satisfaction')
axes[1].set_ylabel('CGPA')

plt.tight_layout()
plt.show()

# Statistical test - So sánh nhóm "High CGPA + Low Satisfaction" với các nhóm khác
from scipy.stats import mannwhitneyu

print("\n=== KIỂM ĐỊNH THỐNG KÊ SO SÁNH CÁC NHÓM ===\n")

# Tạo các nhóm
high_low = df[df['group'] == 'High CGPA + Low Satisfaction']['Depression']
high_high = df[df['group'] == 'High CGPA + High Satisfaction']['Depression']
low_low = df[df['group'] == 'Low CGPA + Low Satisfaction']['Depression']
low_high = df[df['group'] == 'Low CGPA + High Satisfaction']['Depression']

# 1. So sánh High CGPA: Low Sat vs High Sat
u_stat_1, p_val_1 = mannwhitneyu(high_low, high_high, alternative='two-sided')
cohens_d_1 = (high_low.mean() - high_high.mean()) / np.sqrt((high_low.std()**2 + high_high.std()**2) / 2)

print("1. High CGPA: Low Satisfaction vs High Satisfaction")
print(f"   Mann-Whitney U = {u_stat_1:.2f}, p = {p_val_1:.4f}, Cohen's d = {cohens_d_1:.4f}")
print(f"   Chênh lệch: {(high_low.mean() - high_high.mean())*100:.2f} pp")

# 2. So sánh Low CGPA: Low Sat vs High Sat
u_stat_2, p_val_2 = mannwhitneyu(low_low, low_high, alternative='two-sided')
cohens_d_2 = (low_low.mean() - low_high.mean()) / np.sqrt((low_low.std()**2 + low_high.std()**2) / 2)

print("\n2. Low CGPA: Low Satisfaction vs High Satisfaction")
print(f"   Mann-Whitney U = {u_stat_2:.2f}, p = {p_val_2:.4f}, Cohen's d = {cohens_d_2:.4f}")
print(f"   Chênh lệch: {(low_low.mean() - low_high.mean())*100:.2f} pp")

# 3. So sánh cùng Low Satisfaction: High CGPA vs Low CGPA
u_stat_3, p_val_3 = mannwhitneyu(high_low, low_low, alternative='two-sided')
cohens_d_3 = (high_low.mean() - low_low.mean()) / np.sqrt((high_low.std()**2 + low_low.std()**2) / 2)

print("\n3. Low Satisfaction: High CGPA vs Low CGPA")
print(f"   Mann-Whitney U = {u_stat_3:.2f}, p = {p_val_3:.4f}, Cohen's d = {cohens_d_3:.4f}")
print(f"   Chênh lệch: {(high_low.mean() - low_low.mean())*100:.2f} pp")

# 4. Chi-square test cho toàn bộ 4 nhóm
from scipy.stats import chi2_contingency
contingency = pd.crosstab(df['group'], df['Depression'])
chi2, p_overall, dof, expected = chi2_contingency(contingency)

print(f"\n4. Chi-square test (Overall)")
print(f"   Chi2 = {chi2:.4f}, p = {p_overall:.4f}, df = {dof}")

if p_overall < 0.05:
    print(f"   Kết luận: CÓ sự khác biệt có ý nghĩa giữa các nhóm (p < 0.05)")
else:
    print(f"   Kết luận: KHÔNG có sự khác biệt có ý nghĩa (p >= 0.05)")

print("\n=== TÓM TẮT ===")
print(f"- Satisfaction TÁC ĐỘNG MẠNH đến High CGPA: p = {p_val_1:.4f}, Cohen's d = {cohens_d_1:.2f}")
print(f"- Satisfaction TÁC ĐỘNG MẠNH đến Low CGPA: p = {p_val_2:.4f}, Cohen's d = {cohens_d_2:.2f}")
print(f"- CGPA TÁC ĐỘNG khi Low Satisfaction: p = {p_val_3:.4f}, Cohen's d = {cohens_d_3:.2f}")
# Out:
# CGPA threshold (75th percentile): 8.92
# Study Satisfaction threshold: 2
#
# Tỷ lệ trầm cảm theo nhóm:
#                                Depression_Rate  Count
# group
# Low CGPA + Low Satisfaction              0.676   8224
# High CGPA + Low Satisfaction             0.674   3075
# Low CGPA + High Satisfaction             0.529  12658
# High CGPA + High Satisfaction            0.508   3944
# === KIỂM ĐỊNH THỐNG KÊ SO SÁNH CÁC NHÓM ===
#
# 1. High CGPA: Low Satisfaction vs High Satisfaction
#    Mann-Whitney U = 7067196.50, p = 0.0000, Cohen's d = 0.3414
#    Chênh lệch: 16.55 pp
#
# 2. Low CGPA: Low Satisfaction vs High Satisfaction
#    Mann-Whitney U = 59682207.00, p = 0.0000, Cohen's d = 0.3031
#    Chênh lệch: 14.66 pp
#
# 3. Low Satisfaction: High CGPA vs Low CGPA
#    Mann-Whitney U = 12617501.50, p = 0.8298, Cohen's d = -0.0045
#    Chênh lệch: -0.21 pp
#
# 4. Chi-square test (Overall)
#    Chi2 = 637.4286, p = 0.0000, df = 3
# ...

# %% [markdown]
# # Kết luận
#
# ## **Trả lời RQ7: Yếu tố học tập nào ảnh hưởng mạnh nhất?**
#
# Từ kết quả Logistic Regression:
# - **Work/Study Hours**: coefficient = 0.1158, p < 0.001 (có ý nghĩa thống kê cao)
#   - Cứ mỗi giờ học/làm thêm → tăng 12.3% odds của trầm cảm (e^0.1158 ≈ 1.123)
# - **CGPA**: coefficient = 0.0313, p < 0.001 (có ý nghĩa thống kê nhưng tác động yếu)
#   - Cứ mỗi điểm CGPA tăng → tăng 3.2% odds của trầm cảm (e^0.0313 ≈ 1.032)
#   - Tương quan với Depression chỉ r = 0.022 (rất yếu)
#
# **Kết luận**:
# - **Work/Study Hours** (số giờ làm việc/học tập) có tác động **MẠNH GẤP ~4 LẦN** so với CGPA
# - Tác động của Work/Study Hours: 0.1158 vs CGPA: 0.0313
# - Số giờ học/làm việc cao là yếu tố rủi ro chính, không phải điểm số thấp
#
# ---
#
# ## **Trả lời RQ8: Nhóm ngành rủi ro cao**
#
# **Kiểm định thống kê:**
# - Chi-square test: χ² = 531.36, p < 0.0001, df = 27
# - **Kết luận**: CÓ sự khác biệt có ý nghĩa thống kê giữa các ngành
#
# **Top 5 Degree có tỷ lệ trầm cảm cao nhất (n ≥ 100):**
# 1. **'Class 12'**: 70.8% (n=6,080) - Cao hơn trung bình 58.5% đến **+12.3 pp**
# 2. **BSc**: 58.9% (n=888)
# 3. **B.Arch**: 58.9% (n=1,478)
# 4. **BBA**: 58.5% (n=696)
# 5. **MBBS**: 58.0% (n=696)
#
# **Nhóm thấp nhất:**
# - **M.Ed**: 50.5% (n=821) - Thấp hơn trung bình **-8.0 pp**
#
# **Khuyến nghị**: Cần tăng cường hỗ trợ tâm lý đặc biệt cho nhóm **học sinh phổ thông (Class 12)** do áp lực thi cử và định hướng nghề nghiệp.
#
# ---
#
# ## **Trả lời RQ9: Ngưỡng thời gian an toàn**
#
# **Ngưỡng báo động: ~4.1 giờ/ngày** (chính xác: 4.12 giờ)
#
# **Xác suất trầm cảm tại các mốc:**
# - **0 giờ**: 38.5% (thấp nhất)
# - **3 giờ**: 47.0% (dưới ngưỡng)
# - **4.1 giờ**: **50.2%** (**Vượt ngưỡng rủi ro**)
# - **6 giờ**: 55.4%
# - **9 giờ**: 63.8%
# - **12 giờ**: 71.5% (cao nhất)
#
# **Insight:**
# - Dưới 4 giờ/ngày: **Tương đối an toàn** (P < 50%)
# - Từ 4-6 giờ: **Vùng cảnh báo** (P = 50-55%)
# - Trên 6 giờ: **Vùng nguy hiểm** (P > 55%)
# - Mỗi giờ tăng thêm → xác suất trầm cảm tăng ~2.9%
#
# **Khuyến nghị**:
# - Sinh viên nên hạn chế thời gian học/làm việc **dưới 4-6 giờ/ngày**
# - Tập trung vào **chất lượng học tập** (tăng Study Satisfaction) thay vì **số lượng giờ học**
# - Cân bằng giữa học tập và nghỉ ngơi để bảo vệ sức khỏe tâm thần
#
# ---
#
# ## **Trả lời RQ10: Nghịch lý "Học giỏi nhưng không hạnh phúc"**
#
# **Kết quả phân tích:**
#
# So sánh giữa các nhóm sinh viên (CGPA threshold = 8.92 - Top 25%, Study Satisfaction ≤ 2):
#
# | Nhóm | Tỷ lệ Trầm cảm | Số lượng |
# |------|---------------|----------|
# | **Low CGPA + Low Satisfaction** | **67.6%** | 8,224 |
# | **High CGPA + Low Satisfaction** | **67.4%** | 3,075 |
# | Low CGPA + High Satisfaction | 52.9% | 12,658 |
# | High CGPA + High Satisfaction | 50.8% | 3,944 |
#
# **Kiểm định thống kê:**
#
# 1. **High CGPA: Low Satisfaction vs High Satisfaction**
#    - Mann-Whitney U test: p < 0.0001, Cohen's d = **0.34** (effect size trung bình)
#    - Chênh lệch: **+16.6 pp** (67.4% → 50.8%)
#
# 2. **Low CGPA: Low Satisfaction vs High Satisfaction**
#    - Mann-Whitney U test: p < 0.0001, Cohen's d = **0.30** (effect size trung bình)
#    - Chênh lệch: **+14.7 pp** (67.6% → 52.9%)
#
# 3. **Low Satisfaction: High CGPA vs Low CGPA**
#    - Mann-Whitney U test: p = **0.8298** (KHÔNG có ý nghĩa thống kê)
#    - Cohen's d = **-0.00** (không có tác động)
#    - Chênh lệch: chỉ **-0.2 pp** (67.4% vs 67.6%)
#
# 4. **Chi-square test (Overall)**
#    - χ² = 637.43, p < 0.0001, df = 3
#    - **CÓ sự khác biệt có ý nghĩa** giữa các nhóm
#
# **Phát hiện then chốt:**
#
# **Study Satisfaction là yếu tố QUYẾT ĐỊNH:**
# - Satisfaction thấp → Trầm cảm ~67-68% (bất kể CGPA cao hay thấp)
# - Satisfaction cao → Trầm cảm ~51-53% (bất kể CGPA cao hay thấp)
# - Effect size của Satisfaction: Cohen's d = 0.30-0.34 (tác động trung bình-mạnh)
#
# **CGPA KHÔNG tác động khi Satisfaction thấp:**
# - High CGPA + Low Satisfaction (67.4%) ≈ Low CGPA + Low Satisfaction (67.6%)
# - Sự khác biệt 0.2% KHÔNG có ý nghĩa thống kê (p = 0.83)
#
# **Tác động của Satisfaction:**
# - Tăng Satisfaction (từ Low → High) làm giảm trầm cảm **15-17 pp**
# - Đây là **TÁC ĐỘNG MẠNH NHẤT** so với tất cả các yếu tố đã phân tích
#
# **Giải thích nghịch lý:**
# - **Học không vui** → Áp lực, căng thẳng, thiếu động lực nội tại → Trầm cảm
# - Nguyên nhân: học vị áp lực gia đình, học sai ngành, thiếu đam mê, môi trường cạnh tranh độc hại
# - **CGPA cao KHÔNG bảo vệ** khỏi trầm cảm nếu thiếu sự hài lòng với việc học
#
# **Khuyến nghị chiến lược:**
#
# 1. **Ưu tiên tăng Study Satisfaction** thay vì chỉ tập trung vào điểm số
# 2. **Tư vấn định hướng nghề nghiệp** để học đúng ngành yêu thích
# 3. **Tạo môi trường học tập tích cực**, giảm áp lực cạnh tranh độc hại
# 4. **Khuyến khích học tập chủ động** thay vì bị động vì áp lực bên ngoài
